# %%
import requests

# %%
import pandas as pd

# %%
url = 'https://api.upbit.com/v1/candles/minutes/1'

# %%
querystring = {"market" : "KRW-DOGE", "count" : "200"}
headers = {"Accept" : "application/json"}
response = requests.request("GET", url, headers=headers, params = querystring)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"market":"KRW-DOGE","candle_date_time_utc":"2023-03-08T23:49:00","candle_date_time_kst":"2023-03-09T08:49:00","opening_price":95.30000000,"high_price":95.30000000,"low_price":95.20000000,"trade_price":95.30000000,"timestamp":1678319363161,"candle_acc_trade_price":3871311.53529772,"candle_acc_trade_volume":40640.07166210,"unit":1},{"market":"KRW-DOGE","candle_date_time_utc":"2023-03-08T23:48:00","candle_date_time_kst":"2023-03-09T08:48:00","opening_price":95.20000000,"high_price":95.30000000,"low_price":95.20000000,"trade_price":95.30000000,"timestamp":1678319339221,"candle_acc_trade_price":12205824.19897517,"candle_acc_trade_volume":128154.48285096,"unit":1},{"market":"KRW-DOGE","candle_date_time_utc":"2023-03-08T23:47:00","candle_date_time_kst":"2023-03-09T08:47:00","opening_price":95.20000000,"high_price":95.30000000,"low_price":95.20000000,"trade_price":95.20000000,"timestamp":1678319275239,"candle_acc_trade_price":9576510.96083693,"candle_acc_trade_volume":100588.33993578,"uni
# ...

# %%
df = pd.DataFrame(response.json())

# %%
df
# Out:
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-DOGE  2023-03-08T23:49:00  2023-03-09T08:49:00           95.3
# 1    KRW-DOGE  2023-03-08T23:48:00  2023-03-09T08:48:00           95.2
# 2    KRW-DOGE  2023-03-08T23:47:00  2023-03-09T08:47:00           95.2
# 3    KRW-DOGE  2023-03-08T23:46:00  2023-03-09T08:46:00           95.2
# 4    KRW-DOGE  2023-03-08T23:45:00  2023-03-09T08:45:00           95.3
# ..        ...                  ...                  ...            ...
# 195  KRW-DOGE  2023-03-08T20:33:00  2023-03-09T05:33:00           96.7
# 196  KRW-DOGE  2023-03-08T20:32:00  2023-03-09T05:32:00           96.6
# 197  KRW-DOGE  2023-03-08T20:31:00  2023-03-09T05:31:00           96.4
# 198  KRW-DOGE  2023-03-08T20:30:00  2023-03-09T05:30:00           96.4
# 199  KRW-DOGE  2023-03-08T20:29:00  2023-03-09T05:29:00           96.4
#
#      high_price  low_price  trade_price      timestamp  \
# 0          95.3       95.2         95.3  1678319363161
# ...

# %% [markdown]
# ## candle_date_time_kst의 날짜를 없애고 시간만 남기기
# ## ex) 2023-03-08T16:29:00 => 16:29:00
# ## high_price - low_price 계산하기(컬럼 만들어서 diff_price)

# %%
df['diff_price'] = df.high_price - df.low_price

# %%
df
# Out:
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-DOGE  2023-03-08T23:49:00  2023-03-09T08:49:00           95.3
# 1    KRW-DOGE  2023-03-08T23:48:00  2023-03-09T08:48:00           95.2
# 2    KRW-DOGE  2023-03-08T23:47:00  2023-03-09T08:47:00           95.2
# 3    KRW-DOGE  2023-03-08T23:46:00  2023-03-09T08:46:00           95.2
# 4    KRW-DOGE  2023-03-08T23:45:00  2023-03-09T08:45:00           95.3
# ..        ...                  ...                  ...            ...
# 195  KRW-DOGE  2023-03-08T20:33:00  2023-03-09T05:33:00           96.7
# 196  KRW-DOGE  2023-03-08T20:32:00  2023-03-09T05:32:00           96.6
# 197  KRW-DOGE  2023-03-08T20:31:00  2023-03-09T05:31:00           96.4
# 198  KRW-DOGE  2023-03-08T20:30:00  2023-03-09T05:30:00           96.4
# 199  KRW-DOGE  2023-03-08T20:29:00  2023-03-09T05:29:00           96.4
#
#      high_price  low_price  trade_price      timestamp  \
# 0          95.3       95.2         95.3  1678319363161
# ...

# %%
for i in range(len(df)) :
    st = df.iloc[i].candle_date_time_kst
    st2 = st.split('T')[-1]
    df['candle_date_time_kst'].iloc[i] = st2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6980\4174043121.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['candle_date_time_kst'].iloc[i] = st2

# %%
df
# Out:
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-DOGE  2023-03-08T23:49:00             08:49:00           95.3
# 1    KRW-DOGE  2023-03-08T23:48:00             08:48:00           95.2
# 2    KRW-DOGE  2023-03-08T23:47:00             08:47:00           95.2
# 3    KRW-DOGE  2023-03-08T23:46:00             08:46:00           95.2
# 4    KRW-DOGE  2023-03-08T23:45:00             08:45:00           95.3
# ..        ...                  ...                  ...            ...
# 195  KRW-DOGE  2023-03-08T20:33:00             05:33:00           96.7
# 196  KRW-DOGE  2023-03-08T20:32:00             05:32:00           96.6
# 197  KRW-DOGE  2023-03-08T20:31:00             05:31:00           96.4
# 198  KRW-DOGE  2023-03-08T20:30:00             05:30:00           96.4
# 199  KRW-DOGE  2023-03-08T20:29:00             05:29:00           96.4
#
#      high_price  low_price  trade_price      timestamp  \
# 0          95.3       95.2         95.3  1678319363161
# ...

# %%
df['candle_date_time_utc'] = df['candle_date_time_utc'].str[11:]

# %%
df
# Out:
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-DOGE             23:49:00             08:49:00           95.3
# 1    KRW-DOGE             23:48:00             08:48:00           95.2
# 2    KRW-DOGE             23:47:00             08:47:00           95.2
# 3    KRW-DOGE             23:46:00             08:46:00           95.2
# 4    KRW-DOGE             23:45:00             08:45:00           95.3
# ..        ...                  ...                  ...            ...
# 195  KRW-DOGE             20:33:00             05:33:00           96.7
# 196  KRW-DOGE             20:32:00             05:32:00           96.6
# 197  KRW-DOGE             20:31:00             05:31:00           96.4
# 198  KRW-DOGE             20:30:00             05:30:00           96.4
# 199  KRW-DOGE             20:29:00             05:29:00           96.4
#
#      high_price  low_price  trade_price      timestamp  \
# 0          95.3       95.2         95.3  1678319363161
# ...

# %%
url = 'https://api.upbit.com/v1/candles/days'

# %%
querystring = {"market" : "KRW-ETH", "count" : "200"}
headers = {"Accept" : "application/json"}
response = requests.request("GET", url, headers=headers, params = querystring)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'market': 'KRW-ETH',
#   'candle_date_time_utc': '2023-03-09T00:00:00',
#   'candle_date_time_kst': '2023-03-09T09:00:00',
#   'opening_price': 2052000.0,
#   'high_price': 2053000.0,
#   'low_price': 2050000.0,
#   'trade_price': 2051000.0,
#   'timestamp': 1678320236509,
#   'candle_acc_trade_price': 358995346.48545,
#   'candle_acc_trade_volume': 175.08285718,
#   'prev_closing_price': 2050000.0,
#   'change_price': 1000.0,
#   'change_rate': 0.0004878049},
#  {'market': 'KRW-ETH',
#   'candle_date_time_utc': '2023-03-08T00:00:00',
#   'candle_date_time_kst': '2023-03-08T09:00:00',
#   'opening_price': 2077000.0,
#   'high_price': 2089000.0,
#   'low_price': 2045000.0,
#   'trade_price': 2050000.0,
#   'timestamp': 1678319998829,
#   'candle_acc_trade_price': 30247476516.23981,
#   'candle_acc_trade_volume': 14602.47360275,
#   'prev_closing_price': 2077000.0,
#   'change_price': -27000.0,
#   'change_rate': -0.0129995185},
#  {'market': 'KRW-ETH',
# ...

# %%
eth_df = pd.DataFrame(response.json())

# %%
eth_df
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-ETH  2023-03-09T00:00:00  2023-03-09T09:00:00      2052000.0
# 1    KRW-ETH  2023-03-08T00:00:00  2023-03-08T09:00:00      2077000.0
# 2    KRW-ETH  2023-03-07T00:00:00  2023-03-07T09:00:00      2080000.0
# 3    KRW-ETH  2023-03-06T00:00:00  2023-03-06T09:00:00      2092000.0
# 4    KRW-ETH  2023-03-05T00:00:00  2023-03-05T09:00:00      2091000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-ETH  2022-08-26T00:00:00  2022-08-26T09:00:00      2302000.0
# 196  KRW-ETH  2022-08-25T00:00:00  2022-08-25T09:00:00      2255000.0
# 197  KRW-ETH  2022-08-24T00:00:00  2022-08-24T09:00:00      2262000.0
# 198  KRW-ETH  2022-08-23T00:00:00  2022-08-23T09:00:00      2221000.0
# 199  KRW-ETH  2022-08-22T00:00:00  2022-08-22T09:00:00      2216000.0
#
#      high_price  low_price  trade_price      timestamp  \
# 0     2053000.0  2050000.0    2051000.0  1678320236509
# ...

# %% [markdown]
# ### 컬럼을 2개 만들 것 - 5일 전 데이터, 10일 전 데이터

# %%
eth_my_df = eth_df[['market', 'candle_date_time_kst', 'opening_price','high_price', 'low_price', 'trade_price']].copy() # 데이터 프레임 복사

# %%
eth_my_df['candle_date_time_kst'] = eth_my_df['candle_date_time_kst'].str.replace('T09:00:00', '')

# %%
eth_my_df
# Out:
#       market candle_date_time_kst  opening_price  high_price  low_price  \
# 0    KRW-ETH           2023-03-09      2052000.0   2053000.0  2050000.0
# 1    KRW-ETH           2023-03-08      2077000.0   2089000.0  2045000.0
# 2    KRW-ETH           2023-03-07      2080000.0   2106000.0  2049000.0
# 3    KRW-ETH           2023-03-06      2092000.0   2105000.0  2066000.0
# 4    KRW-ETH           2023-03-05      2091000.0   2110000.0  2072000.0
# ..       ...                  ...            ...         ...        ...
# 195  KRW-ETH           2022-08-26      2302000.0   2315000.0  2060000.0
# 196  KRW-ETH           2022-08-25      2255000.0   2335000.0  2251000.0
# 197  KRW-ETH           2022-08-24      2262000.0   2300000.0  2202000.0
# 198  KRW-ETH           2022-08-23      2221000.0   2277000.0  2142000.0
# 199  KRW-ETH           2022-08-22      2216000.0   2224000.0  2112000.0
#
#      trade_price
# 0      2051000.0
# 1      2050000.0
# 2      2077000.0
# 3      2080000.0
# ...

# %%
eth_my_df[eth_my_df.candle_date_time_kst == '2022-08-22']
# Out:
#       market candle_date_time_kst  opening_price  high_price  low_price  \
# 199  KRW-ETH           2022-08-22      2216000.0   2224000.0  2112000.0
#
#      trade_price
# 199    2221000.0

# %%
eth_my_df.set_index('candle_date_time_kst', inplace=True) # candle_date_time_kst 컬럼이 index가 됨.

# %%
eth_my_df
# Out:
#                        market  opening_price  high_price  low_price  \
# candle_date_time_kst
# 2023-03-09            KRW-ETH      2052000.0   2053000.0  2050000.0
# 2023-03-08            KRW-ETH      2077000.0   2089000.0  2045000.0
# 2023-03-07            KRW-ETH      2080000.0   2106000.0  2049000.0
# 2023-03-06            KRW-ETH      2092000.0   2105000.0  2066000.0
# 2023-03-05            KRW-ETH      2091000.0   2110000.0  2072000.0
# ...                       ...            ...         ...        ...
# 2022-08-26            KRW-ETH      2302000.0   2315000.0  2060000.0
# 2022-08-25            KRW-ETH      2255000.0   2335000.0  2251000.0
# 2022-08-24            KRW-ETH      2262000.0   2300000.0  2202000.0
# 2022-08-23            KRW-ETH      2221000.0   2277000.0  2142000.0
# 2022-08-22            KRW-ETH      2216000.0   2224000.0  2112000.0
#
#                       trade_price
# candle_date_time_kst
# 2023-03-09              2051000.0
# 2023-03-08              2050000.0
# ...

# %%
eth_my_df.loc[['2023-01-01']]
# Out:
#                        market  opening_price  high_price  low_price  \
# candle_date_time_kst
# 2023-01-01            KRW-ETH      1524000.0   1535500.0  1519000.0
#
#                       trade_price
# candle_date_time_kst
# 2023-01-01              1528000.0

# %%
eth_my_df.iloc[[13]] # series는 [] DataFrame은 [[]]
# Out:
#                        market  opening_price  high_price  low_price  \
# candle_date_time_kst
# 2022-09-04            KRW-ETH      2153000.0   2184000.0  2135000.0
#
#                       trade_price  m5
# candle_date_time_kst
# 2022-09-04              2173000.0 NaN

# %%
eth_my_df = eth_my_df[::-1] # 역방향 정렬.

# %%
eth_my_df
# Out:
#                        market  opening_price  high_price  low_price  \
# candle_date_time_kst
# 2022-08-22            KRW-ETH      2216000.0   2224000.0  2112000.0
# 2022-08-23            KRW-ETH      2221000.0   2277000.0  2142000.0
# 2022-08-24            KRW-ETH      2262000.0   2300000.0  2202000.0
# 2022-08-25            KRW-ETH      2255000.0   2335000.0  2251000.0
# 2022-08-26            KRW-ETH      2302000.0   2315000.0  2060000.0
# ...                       ...            ...         ...        ...
# 2023-03-05            KRW-ETH      2091000.0   2110000.0  2072000.0
# 2023-03-06            KRW-ETH      2092000.0   2105000.0  2066000.0
# 2023-03-07            KRW-ETH      2080000.0   2106000.0  2049000.0
# 2023-03-08            KRW-ETH      2077000.0   2089000.0  2045000.0
# 2023-03-09            KRW-ETH      2052000.0   2053000.0  2050000.0
#
#                       trade_price
# candle_date_time_kst
# 2022-08-22              2221000.0
# 2022-08-23              2263000.0
# ...

# %% [markdown]
# ### 컬럼 만들기
# ### 1. trade_price의 5일 동안 평균 담기(m5)
# ### 2. trade_price의 10일 동안 평균 담기(m10)

# %%
eth_my_df[18-5 : 18].groupby().mean()
eth_my_df[18-5 : 18].groupby('trade_price').mean().round(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6980\1151170603.py in <module>
# ----> 1 eth_my_df[18-5 : 18].groupby().mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713
#    7714         if level is None and by is None:
# -> 7715             raise TypeError("You have to supply one of 'by' and 'level'")
#    7716         axis = self._get_axis_number(axis)
#    7717
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
eth_my_df[0 : 5].groupby('market').mean().round(2)[['trade_price']]
# Out:
#          trade_price
# market
# KRW-ETH    2225000.0

# %%
 eth_my_df[['trade_price']].iloc[[5]]
# Out:
#                       trade_price
# candle_date_time_kst
# 2022-08-27              2063000.0

# %%
for i in range(len(eth_my_df)) :
    pre_idx = i;
    post_idx = i+5;
    eth_my_df['m5'].iloc[[post_idx]] = eth_my_df[pre_idx : post_idx].groupby('market').mean().round(2)[['trade_price']]
    
    if i + 5 > len(eth_my_df) :
        break
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6980\1045881322.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth_my_df['m5'].iloc[[post_idx]] = eth_my_df[pre_idx : post_idx].groupby('market').mean().round(2)[['trade_price']]
# C:\Users\user\AppData\Local\Temp\ipykernel_6980\1045881322.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth_my_df['m5'].iloc[[post_idx]] = eth_my_df[pre_idx : post_idx].groupby('market').mean().round(2)[['trade_price']]
# C:\Users\user\AppData\Local\Temp\ipykernel_6980\1045881322.py:4: SettingWithCopyWarning:
# ...

# %%
eth_my_df
# Out:
#                        market  opening_price  high_price  low_price  \
# candle_date_time_kst
# 2022-08-22            KRW-ETH      2216000.0   2224000.0  2112000.0
# 2022-08-23            KRW-ETH      2221000.0   2277000.0  2142000.0
# 2022-08-24            KRW-ETH      2262000.0   2300000.0  2202000.0
# 2022-08-25            KRW-ETH      2255000.0   2335000.0  2251000.0
# 2022-08-26            KRW-ETH      2302000.0   2315000.0  2060000.0
# ...                       ...            ...         ...        ...
# 2023-03-05            KRW-ETH      2091000.0   2110000.0  2072000.0
# 2023-03-06            KRW-ETH      2092000.0   2105000.0  2066000.0
# 2023-03-07            KRW-ETH      2080000.0   2106000.0  2049000.0
# 2023-03-08            KRW-ETH      2077000.0   2089000.0  2045000.0
# 2023-03-09            KRW-ETH      2052000.0   2053000.0  2050000.0
#
#                       trade_price         m5
# candle_date_time_kst
# 2022-08-22              2221000.0        NaN
# ...

# %%
eth_my_df.drop('m5', axis = 1)
# Out:
#                        market  opening_price  high_price  low_price  \
# candle_date_time_kst
# 2022-08-22            KRW-ETH      2216000.0   2224000.0  2112000.0
# 2022-08-23            KRW-ETH      2221000.0   2277000.0  2142000.0
# 2022-08-24            KRW-ETH      2262000.0   2300000.0  2202000.0
# 2022-08-25            KRW-ETH      2255000.0   2335000.0  2251000.0
# 2022-08-26            KRW-ETH      2302000.0   2315000.0  2060000.0
# ...                       ...            ...         ...        ...
# 2023-03-05            KRW-ETH      2091000.0   2110000.0  2072000.0
# 2023-03-06            KRW-ETH      2092000.0   2105000.0  2066000.0
# 2023-03-07            KRW-ETH      2080000.0   2106000.0  2049000.0
# 2023-03-08            KRW-ETH      2077000.0   2089000.0  2045000.0
# 2023-03-09            KRW-ETH      2052000.0   2053000.0  2050000.0
#
#                       trade_price
# candle_date_time_kst
# 2022-08-22              2221000.0
# 2022-08-23              2263000.0
# ...

# %%
for i in range(len(eth_my_df)) :
    pre_idx = i;
    post_idx = i+10;
    eth_my_df['m10'].iloc[[post_idx]] = eth_my_df[pre_idx : post_idx].groupby('market').mean().round(2)[['trade_price']]
    
    if post_idx > len(eth_my_df) :
        break
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6980\2858458868.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth_my_df['m10'].iloc[[post_idx]] = eth_my_df[pre_idx : post_idx].groupby('market').mean().round(2)[['trade_price']]
# C:\Users\user\AppData\Local\Temp\ipykernel_6980\2858458868.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth_my_df['m10'].iloc[[post_idx]] = eth_my_df[pre_idx : post_idx].groupby('market').mean().round(2)[['trade_price']]
# C:\Users\user\AppData\Local\Temp\ipykernel_6980\2858458868.py:4: SettingWithCopyWarning:
# ...

# %%
eth_my_df[:15]
# Out:
#                        market  opening_price  high_price  low_price  \
# candle_date_time_kst
# 2022-08-22            KRW-ETH      2216000.0   2224000.0  2112000.0
# 2022-08-23            KRW-ETH      2221000.0   2277000.0  2142000.0
# 2022-08-24            KRW-ETH      2262000.0   2300000.0  2202000.0
# 2022-08-25            KRW-ETH      2255000.0   2335000.0  2251000.0
# 2022-08-26            KRW-ETH      2302000.0   2315000.0  2060000.0
# 2022-08-27            KRW-ETH      2086000.0   2102000.0  2010000.0
# 2022-08-28            KRW-ETH      2063000.0   2090000.0  1975000.0
# 2022-08-29            KRW-ETH      1978000.0   2138000.0  1970500.0
# 2022-08-30            KRW-ETH      2126000.0   2203000.0  2047000.0
# 2022-08-31            KRW-ETH      2101000.0   2209000.0  2100000.0
# 2022-09-01            KRW-ETH      2136000.0   2193000.0  2098000.0
# 2022-09-02            KRW-ETH      2176000.0   2260000.0  2145000.0
# ...

# %%
for i in range(len(my_df)) :
    m5 = my_df.iloc[i-5 : i].trade_price.mean()
    my_df['m5'].iloc[i] = m5
    
    m10 = my_df.iloc[i-10 : i].trade_price.mean()
    my_df['m5'].iloc[i] = m5

# %%
eth_my_df = eth_my_df.fillna(0)

# %%
eth_my_df
# Out:
#                        market  opening_price  high_price  low_price  \
# candle_date_time_kst
# 2022-08-22            KRW-ETH      2216000.0   2224000.0  2112000.0
# 2022-08-23            KRW-ETH      2221000.0   2277000.0  2142000.0
# 2022-08-24            KRW-ETH      2262000.0   2300000.0  2202000.0
# 2022-08-25            KRW-ETH      2255000.0   2335000.0  2251000.0
# 2022-08-26            KRW-ETH      2302000.0   2315000.0  2060000.0
# ...                       ...            ...         ...        ...
# 2023-03-05            KRW-ETH      2091000.0   2110000.0  2072000.0
# 2023-03-06            KRW-ETH      2092000.0   2105000.0  2066000.0
# 2023-03-07            KRW-ETH      2080000.0   2106000.0  2049000.0
# 2023-03-08            KRW-ETH      2077000.0   2089000.0  2045000.0
# 2023-03-09            KRW-ETH      2052000.0   2053000.0  2050000.0
#
#                       trade_price         m5        m10
# candle_date_time_kst
# ...

# %%
api_key = '5478465a5763686a313037546a74786f'
url = f'http://openapi.seoul.go.kr:8088/{api_key}/json/tbLnOpendataRentV/1/1000/'

# %%
res = requests.get(url).json()

# %%
res
# Out:
# {'tbLnOpendataRentV': {'list_total_count': 5229630,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'ACC_YEAR': '2023',
#     'SGG_CD': '11500',
#     'SGG_NM': '강서구',
#     'BJDONG_CD': '10800',
#     'BJDONG_NM': '공항동',
#     'LAND_GBN': '1',
#     'LAND_GBN_NM': '대지',
#     'BOBN': '0675',
#     'BUBN': '0009',
#     'FLR_NO': 5.0,
#     'CNTRCT_DE': '20230307',
#     'RENT_GBN': '전세',
#     'RENT_AREA': 26.03,
#     'RENT_GTN': '20000',
#     'RENT_FEE': '0',
#     'BLDG_NM': '위하우스',
#     'BUILD_YEAR': '2021',
#     'HOUSE_GBN_NM': '연립다세대',
#     'CNTRCT_PRD': '',
#     'NEW_RON_SECD': '',
#     'CNTRCT_UPDT_RQEST_AT': '',
#     'BEFORE_GRNTY_AMOUNT': '',
#     'BEFORE_MT_RENT_CHRGE': ''},
#    {'ACC_YEAR': '2023',
#     'SGG_CD': '11305',
#     'SGG_NM': '강북구',
#     'BJDONG_CD': '10100',
#     'BJDONG_NM': '미아동',
#     'LAND_GBN': '1',
#     'LAND_GBN_NM': '대지',
#     'BOBN': '1354',
#     'BUBN': '0001',
#     'FLR_NO': 13.0,
# ...

# %%
res.keys()
# Out:
# dict_keys(['tbLnOpendataRentV'])

# %%
key = list(res.keys())[0]

# %%
key
# Out:
# 'tbLnOpendataRentV'

# %%
len(res[key]['row'])
# Out:
# 1000

# %%
df = pd.DataFrame(res[key]['row'])

# %%
df.columns
# Out:
# Index(['ACC_YEAR', 'SGG_CD', 'SGG_NM', 'BJDONG_CD', 'BJDONG_NM', 'LAND_GBN',
#        'LAND_GBN_NM', 'BOBN', 'BUBN', 'FLR_NO', 'CNTRCT_DE', 'RENT_GBN',
#        'RENT_AREA', 'RENT_GTN', 'RENT_FEE', 'BLDG_NM', 'BUILD_YEAR',
#        'HOUSE_GBN_NM', 'CNTRCT_PRD', 'NEW_RON_SECD', 'CNTRCT_UPDT_RQEST_AT',
#        'BEFORE_GRNTY_AMOUNT', 'BEFORE_MT_RENT_CHRGE'],
#       dtype='object')

# %%
sel_c = ['SGG_NM', 'BJDONG_NM', 'LAND_GBN_NM', 'FLR_NO', 'CNTRCT_DE', 'RENT_GBN', 'RENT_AREA', 'RENT_GTN', 'RENT_FEE', 'BLDG_NM', 'BUILD_YEAR']

# %%
my_df = df[sel_c]

# %%
my_df.columns = ['자치구명', '법정동명', '지번구분명', '층수', '계약일', '전월세', '면적', '보증금', '임대료', '건물명', '건축년도']

# %%
my_df
# Out:
#      자치구명   법정동명 지번구분명    층수       계약일 전월세     면적    보증금  임대료          건물명  \
# 0     강서구    공항동    대지   5.0  20230307  전세  26.03  20000    0         위하우스
# 1     강북구    미아동    대지  13.0  20230307  월세  32.94   1349   17  벽산라이브파크(임대)
# 2     송파구    거여동    대지   8.0  20230307  월세  39.76   6582   10   위례포레샤인13단지
# 3    서대문구  충정로3가    대지   3.0  20230307  전세  78.69  30000    0           보광
# 4     강서구    공항동    대지   5.0  20230307  전세  35.21  23500    0         웰스캐슬
# ..    ...    ...   ...   ...       ...  ..    ...    ...  ...          ...
# 995   강남구    수서동    대지   4.0  20230306  월세  59.86   5000  150           삼성
# 996   강서구    화곡동    대지  11.0  20230306  전세  17.92  14500    0           포유
# 997   관악구    봉천동    대지   2.0  20230306  전세  59.92  38000    0           두산
# 998   은평구    대조동    대지  11.0  20230306  전세  56.83  35000    0       호림리슈리안
# 999   강북구    미아동    대지  19.0  20230306  전세  84.71  38000    0       삼각산아이원
#
#      건축년도
# 0    2021
# 1    2004
# 2    2020
# 3    1996
# ...

# %%
my_df.columns
# Out:
# Index(['자치구명', '법정동명', '지번구분명', '층수', '계약일', '전월세', '면적', '보증금', '임대료', '건물명',
#        '건축년도'],
#       dtype='object')

# %% [markdown]
# ### 전월세 = 전세/월세 - 전세만 뽑아서 데이터 프레임 만들기
# ### astype => 보증금을 astype으로 int, float으로 변경
# ### 분리된 데이터 프레임으로 자치구명을 기준으로 groupby를 해서 보증금과 임대료를 두가지의 평균
# ### groupby된 데이터 프레임을 sort해서 내림차 순으로 정렬
# ### 임대료 / 보증금 round(4) 해서 값 구하기

# %%
my_df.iloc[0]['전월세'] df2 = df[df['label'] == 'FAIL']
# Out:
# '전세'

# %%
long_lease_df = my_df[my_df['전월세'] == '전세']
short_lease_df = my_df[my_df['전월세'] == '월세']

# %%
long_lease_df
# Out:
#      자치구명    법정동명 지번구분명    층수       계약일 전월세      면적     보증금 임대료      건물명  건축년도
# 0     강서구     공항동    대지   5.0  20230307  전세   26.03   20000   0     위하우스  2021
# 3    서대문구   충정로3가    대지   3.0  20230307  전세   78.69   30000   0       보광  1996
# 4     강서구     공항동    대지   5.0  20230307  전세   35.21   23500   0     웰스캐슬  2017
# 7      중구  남대문로5가    대지  33.0  20230307  전세  142.23  120000   0  남산트라팰리스  2010
# 8     성동구     행당동    대지  14.0  20230307  전세   59.27   47500   0  이수브라운스톤  2005
# ..    ...     ...   ...   ...       ...  ..     ...     ...  ..      ...   ...
# 994   서초구     서초동    대지  10.0  20230306  전세   19.27   20000   0   청화오피스텔
# 996   강서구     화곡동    대지  11.0  20230306  전세   17.92   14500   0       포유  2018
# 997   관악구     봉천동    대지   2.0  20230306  전세   59.92   38000   0       두산  2000
# 998   은평구     대조동    대지  11.0  20230306  전세   56.83   35000   0   호림리슈리안  2018
# 999   강북구     미아동    대지  19.0  20230306  전세   84.71   38000   0   삼각산아이원  2003
#
# [526 rows x 11 columns]

# %%
short_lease_df
# Out:
#      자치구명 법정동명 지번구분명    층수       계약일 전월세     면적    보증금  임대료          건물명  건축년도
# 1     강북구  미아동    대지  13.0  20230307  월세  32.94   1349   17  벽산라이브파크(임대)  2004
# 2     송파구  거여동    대지   8.0  20230307  월세  39.76   6582   10   위례포레샤인13단지  2020
# 5     서초구  우면동    대지   6.0  20230307  월세  49.90   4163   30    서초네이처힐3단지  2013
# 6     성북구  정릉동    대지   5.0  20230307  월세  84.09   5000  130      정릉풍림아이원  2005
# 11    노원구  상계동    대지   9.0  20230307  월세  43.35  12000   20           벽산  1989
# ..    ...  ...   ...   ...       ...  ..    ...    ...  ...          ...   ...
# 985   강동구  성내동    대지   5.0  20230306  월세  17.17    500   58       드림빌하우스  2013
# 988  동대문구  신설동    대지   4.0  20230306  월세  20.12   3000   83         캐슬루체  2023
# 990   마포구  서교동         0.0  20230306  월세  26.40   1000   80               2002
# 991   성북구  정릉동    대지   4.0  20230306  월세  47.44   1000   80     삼성그린빌라2차  2002
# 995   강남구  수서동    대지   4.0  20230306  월세  59.86   5000  150           삼성  1997
#
# [474 rows x 11 columns]

# %%
long_lease_df.dtypes
# Out:
# 자치구명      object
# 법정동명      object
# 지번구분명     object
# 층수       float64
# 계약일       object
# 전월세       object
# 면적       float64
# 보증금       object
# 임대료       object
# 건물명       object
# 건축년도      object
# dtype: object

# %%
long_df = long_lease_df.astype({'보증금' : 'float', '임대료' : 'float'})

# %%
short_df = short_lease_df.astype({'보증금' : 'float', '임대료' : 'float'})

# %%
short_lease_df.groupby('보증금').mean()
# Out:
#              층수         면적
# 보증금
# 0      0.000000  36.275000
# 10     0.000000  20.000000
# 100    0.000000  12.600000
# 1000   4.054054  31.908649
# 10000  5.911765  55.222941
# ...         ...        ...
# 967    3.500000  39.360000
# 9850   4.000000  14.850000
# 9905   6.000000  34.470000
# 9928   7.000000  49.900000
# 998    6.666667  32.400000
#
# [151 rows x 2 columns]

# %%
short_lease_df.dtypes
# Out:
# 자치구명      object
# 법정동명      object
# 지번구분명     object
# 층수       float64
# 계약일       object
# 전월세       object
# 면적       float64
# 보증금       object
# 임대료       object
# 건물명       object
# 건축년도      object
# dtype: object

# %%
long_lease_df
# Out:
#      자치구명    법정동명 지번구분명    층수       계약일 전월세      면적     보증금 임대료      건물명  건축년도
# 0     강서구     공항동    대지   5.0  20230307  전세   26.03   20000   0     위하우스  2021
# 3    서대문구   충정로3가    대지   3.0  20230307  전세   78.69   30000   0       보광  1996
# 4     강서구     공항동    대지   5.0  20230307  전세   35.21   23500   0     웰스캐슬  2017
# 7      중구  남대문로5가    대지  33.0  20230307  전세  142.23  120000   0  남산트라팰리스  2010
# 8     성동구     행당동    대지  14.0  20230307  전세   59.27   47500   0  이수브라운스톤  2005
# ..    ...     ...   ...   ...       ...  ..     ...     ...  ..      ...   ...
# 994   서초구     서초동    대지  10.0  20230306  전세   19.27   20000   0   청화오피스텔
# 996   강서구     화곡동    대지  11.0  20230306  전세   17.92   14500   0       포유  2018
# 997   관악구     봉천동    대지   2.0  20230306  전세   59.92   38000   0       두산  2000
# 998   은평구     대조동    대지  11.0  20230306  전세   56.83   35000   0   호림리슈리안  2018
# 999   강북구     미아동    대지  19.0  20230306  전세   84.71   38000   0   삼각산아이원  2003
#
# [526 rows x 11 columns]

# %%
long_lease_df['보증금']
# Out:
# 0       20000
# 3       30000
# 4       23500
# 7      120000
# 8       47500
#         ...
# 994     20000
# 996     14500
# 997     38000
# 998     35000
# 999     38000
# Name: 보증금, Length: 526, dtype: object

# %%
long_df.dtypes
# Out:
# 자치구명      object
# 법정동명      object
# 지번구분명     object
# 층수       float64
# 계약일       object
# 전월세       object
# 면적       float64
# 보증금      float64
# 임대료      float64
# 건물명       object
# 건축년도      object
# dtype: object

# %%
short_df.dtypes
# Out:
# 자치구명      object
# 법정동명      object
# 지번구분명     object
# 층수       float64
# 계약일       object
# 전월세       object
# 면적       float64
# 보증금      float64
# 임대료      float64
# 건물명       object
# 건축년도      object
# dtype: object

# %%
long_df.groupby('자치구명').mean()
# Out:
#              층수         면적           보증금       임대료
# 자치구명
# 강남구    6.694444  70.481111  59712.638889  0.000000
# 강동구    6.166667  59.956250  33319.625000  0.000000
# 강북구    5.818182  62.841818  22281.818182  0.000000
# 강서구    6.162162  46.362973  27325.405405  0.054054
# 관악구    2.695652  43.762609  21315.217391  0.000000
# 광진구    3.120000  38.829600  25278.000000  0.000000
# 구로구    7.333333  54.626667  31470.000000  0.000000
# 금천구    8.444444  45.058889  16625.888889  0.000000
# 노원구    6.190476  54.913333  26265.000000  0.000000
# 도봉구    5.733333  62.234000  24780.000000  0.000000
# 동대문구   6.555556  45.868889  28333.333333  0.000000
# 동작구    6.750000  58.383750  33587.500000  0.000000
# 마포구    6.000000  49.130714  27685.714286  0.000000
# 서대문구   5.187500  69.118750  37131.125000  0.000000
# 서초구    8.320755  64.760566  31942.037736  0.000000
# 성동구    6.176471  54.512353  32750.000000  0.000000
# 성북구    5.800000  59.225600  26212.000000  0.000000
# ...

# %%
group_short = short_df.groupby('자치구명').mean().round(2).sort_values(by = ['보증금'])

# %%
group_long = long_df.groupby('자치구명').mean().round(2).sort_values(by = ['보증금'])

# %%
group_short['임대료/보증금'] = round(group_short['보증금'] / group_short['임대료'], 2)

# %%
group_short.sort_values(by= '임대료/보증금', ascending = False)
# Out:
#         층수     면적       보증금    임대료  임대료/보증금
# 자치구명
# 서초구   5.96  64.94  23977.80  66.04   363.08
# 양천구   4.55  48.32   9387.30  41.65   225.39
# 성동구   7.27  34.36   6976.91  31.91   218.64
# 은평구   4.79  43.96   7489.21  34.67   216.01
# 동작구   2.00  41.63   7722.78  38.28   201.74
# 강동구   4.30  51.03  12028.35  62.48   192.52
# 영등포구  7.05  40.15   9961.05  53.75   185.32
# 강남구   5.57  50.58  15574.43  91.64   169.95
# 노원구   9.20  48.40   8112.95  51.85   156.47
# 구로구   7.35  52.19   8825.24  56.59   155.95
# 송파구   5.33  54.49  14253.13  92.64   153.86
# 중랑구   3.19  42.12   6590.88  44.92   146.72
# 종로구   1.33  48.04   6920.67  47.67   145.18
# 서대문구  6.80  37.78   5044.55  35.00   144.13
# 강서구   3.27  27.92   5234.00  36.67   142.73
# 금천구   2.80  48.78   5282.00  41.00   128.83
# 동대문구  6.68  37.95   5187.39  43.00   120.64
# 성북구   4.89  45.48   5870.89  49.79   117.91
# 용산구   4.57  53.23   8743.86  79.14   110.49
# 광진구   2.17  31.44   5539.13  50.65   109.36
# ...

# %%
import cx_Oracle as co

# %%
import pymysql as pms

# %%
# 오라클
dsn = co.makedsn('localhost', 1521, 'xe')
db = co.connect(user = 'icia', password = '1111', dsn = dsn)

# %%
cursor = db.cursor()

# %%
cursor
# Out:
# <function Connection.cursor>

# %%
#mySQL
conn = pms.connect(host = 'localhost', user = 'root', password = '1111', db = 'icia', charset='utf8')
sql = conn.cursor()

# %%
# 오라클 쿼리
query = 'create table test2(id number(1), name varchar(5), constraint test113_pk primary key(id))'

# %%
# mysql 쿼리
query2 = 'create table test_mysql(id smallint, name varchar(5))'

# %%
cursor.execute(query)

# %%
query3 = 'select * from test2'

# %%
pd.read_sql(sql=query3,con=db)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Empty DataFrame
# Columns: [ID, NAME]
# Index: []

# %%
sql.execute(query2)
# Out:
# 0

# %%
query3 = 'select * from test_mysql'

# %%
pd.read_sql(sql=query3, con= conn)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Empty DataFrame
# Columns: [id, name]
# Index: []
